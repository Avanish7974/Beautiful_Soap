# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.croma.com/campaign/croma-collections/c/6712?q=%3Arelevance&utm_source=google&utm_medium=ps&utm_campaign=Sok_PMax-Croma_OL_Test&gad_source=1&gad_campaignid=22429131595&gbraid=0AAAAADv7K37nAzdLQzpyOMaiCKjHp6AoV&gclid=CjwKCAjwlOrFBhBaEiwAw4bYDeU276GzoMPVxY6VakWH5gkapVCnoPz7w6gvKhXbxmEoAMUGRy-uEBoCi8EQAvD_BwE"

# %%
r = requests.get(url)
print(r)  # to check the status code of the request
# respone = 200  # if the status code is 200, it means the request was successful
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,"lxml")
print(soup)
 # to print the HTML content of the page in a formatted way
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <script async="" defer="" src="https://accounts.tatadigital.com/v2/tdl-sso-auth.js"></script>
# <script></script>
# <meta charset="utf-8"/>
# <meta content="" data-react-helmet="true" name="title"/>
# <meta content="" data-react-helmet="true" property="og:title"/>
# <meta content="" data-react-helmet="true" name="description"/>
# <meta content="" data-react-helmet="true" property="og:description"/>
# <meta content="index,follow" data-react-helmet="true" name="robots"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" id="viewport" name="viewport"/>
# <meta content="#49a5a2" name="theme-color"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="CROMA-WEB-APP" name="tdl-sso-client_id"/>
# <link href="/assets/favicon.ico" rel="shortcut icon" sizes="16x16 32x32 64x64" type="image/x-icon"/>
# ...

# %%
np = soup.find("a",class_ = "css-146c3p1 r-1awozwy r-1tcj4yv r-1vgyyaa r-1b43r93 r-1777fci r-1dpkw9").get("href")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np = soup.find("a",class_ = "css-146c3p1 r-1awozwy r-1tcj4yv r-1vgyyaa r-1b43r93 r-1777fci r-1dpkw9").get("href")
#
# AttributeError: 'NoneType' object has no attribute 'get'
